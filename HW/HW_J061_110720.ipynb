# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
class DataRead():
    def __init__(self,fname):
        self.data = pd.read_csv(fname)
        
    def RowSelect(self,x,y):
        print(self.data.iloc[x-1,y-1])
        print(self.data.iloc[y-1])
        
        
class DataRead2(DataRead):
    def CorrelationPlot(self):
        data1 = self.data
        correlation_plot = data1.corr()
        sns.heatmap(correlation_plot, annot = True)
        plt.show()
    
    def RowSelect(self,x,y,z):
        print(self.data.iloc[x-1])
        print(self.data.iloc[y-1])
        print(self.data.iloc[z-1])

# %%
a = DataRead2("D:/College/SEM 4/SM_1/PROJECT/fframingham.csv")
a.CorrelationPlot()

# %%
a.RowSelect(1,2,3)
# Out:
# male                 1.00
# age                 39.00
# currentSmoker        0.00
# cigsPerDay           0.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         0.00
# diabetes             0.00
# totChol            195.00
# sysBP              106.00
# diaBP               70.00
# BMI                 26.97
# heartRate           80.00
# glucose             77.00
# CHD                  0.00
# Name: 0, dtype: float64
# male                 0.00
# age                 46.00
# currentSmoker        0.00
# cigsPerDay           0.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         0.00
# diabetes             0.00
# totChol            250.00
# sysBP              121.00
# diaBP               81.00
# BMI                 28.73
# heartRate           95.00
# glucose             76.00
# CHD                  0.00
# Name: 1, dtype: float64
# male                 1.00
# age                 48.00
# currentSmoker        1.00
# cigsPerDay          20.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         0.00
# diabetes             0.00
# totChol            245.00
# sysBP              127.50
# diaBP               80.00
# BMI                 25.34
# heartRate           75.00
# glucose             70.00
# CHD                  0.00
# Name: 2, dtype: float64

# %%
filepath = input("Enter the file path\n")
option = input ("Enter 1: Correlation Plot \nEnter 2: Display Rows\n")
option = int(option)
if (option == 1):
    df = DataRead2(filepath)
    df.CorrelationPlot()
elif (option == 2):
    x = input("Enter Row:\n")
    x = int(x)
    y = input("Enter Row:\n")
    y = int(y)
    z = input("Enter Row:\n")
    z = int(z)
    df = DataRead2(filepath)
    df.RowSelect(x,y,z)
else:
    print("Invalid option")
# Out:
# Enter the file path
# D:/College/SEM 4/SM_1/PROJECT/fframingham.csv
# Enter 1: Correlation Plot
# Enter 2: Display Rows
# 2
# Enter Line:
# 5
# Enter Line:
# 10
# Enter Line:
# 19
# male                 0.0
# age                 46.0
# currentSmoker        1.0
# cigsPerDay          23.0
# BPMeds               0.0
# prevalentStroke      0.0
# prevalentHyp         0.0
# diabetes             0.0
# totChol            285.0
# sysBP              130.0
# diaBP               84.0
# BMI                 23.1
# heartRate           85.0
# glucose             85.0
# CHD                  0.0
# Name: 4, dtype: float64
# male                 1.00
# age                 43.00
# currentSmoker        1.00
# cigsPerDay          30.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         1.00
# diabetes             0.00
# totChol            225.00
# sysBP              162.00
# diaBP              107.00
# BMI                 23.61
# heartRate           93.00
# glucose             88.00
# CHD                  0.00
# Name: 9, dtype: float64
# male                 0.00
# age                 38.00
# currentSmoker        1.00
# cigsPerDay           5.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         0.00
# diabetes             0.00
# totChol            195.00
# sysBP              122.00
# diaBP               84.50
# BMI                 23.24
# heartRate           75.00
# glucose             78.00
# CHD                  0.00
# Name: 18, dtype: float64
